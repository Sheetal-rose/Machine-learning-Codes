# %%
import pandas as pd
import io

df = pd.read_csv('/content/HOME DATASET.CSV')
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# ID              0
# Location        0
# Unnamed: 2     10
#  size(sqft)     1
# room            1
# age(year)       1
# price(INR)      1
# dtype: int64

# %%
df['price(INR)'] = df['price(INR)'].astype(float)

# Convert 'room' column to numeric, coercing errors
df['room'] = pd.to_numeric(df['room'], errors='coerce')

numerical_cols = [' size(sqft)', 'room', 'age(year)', 'price(INR)']
for col in numerical_cols:
  # Check if the column is numeric before calculating median and filling NaNs
  if pd.api.types.is_numeric_dtype(df[col]):
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)
  else:
    print(f"Warning: Column '{col}' is not numeric and will not be imputed with median.")


print("Missing values after imputation:")
print(df.isnull().sum())
display(df)
# Out:
# Missing values after imputation:
# ID              0
# Location        0
# Unnamed: 2     10
#  size(sqft)     0
# room            0
# age(year)       0
# price(INR)      0
# dtype: int64
#    ID Location   Unnamed: 2   size(sqft)  room  age(year)  price(INR)
# 0   1  Downtown         NaN       1200.0   3.0       10.0   5000000.0
# 1   2    Suburb         NaN       1500.0   4.0        5.0   6500000.0
# 2   3    Uptown         NaN        100.0   2.0       20.0   3800000.0
# 3   4    Sunurb         NaN        200.0   5.0       10.0   7200000.0
# 4   5  Downtown         NaN        850.0   3.0       15.0   4200000.0
# 5   6    Uptown         NaN       1100.0   3.0       12.0   5600000.0
# 6   7    Suburb         NaN       1100.0   3.0        7.0   4800000.0
# 7   8  Downtown         NaN       1750.0   4.0        3.0   7000000.0
# 8   9    Uptown         NaN        950.0   2.0       25.0   3500000.0
# 9  10    Suburb         NaN       1600.0   4.0        6.0   5000000.0

# %%
duplicate_rows = df[df.duplicated()]
print("Duplicate rows found:")
display(duplicate_rows)


df_cleaned = df.drop_duplicates()
print("\nDataFrame after removing duplicate rows:")
display(df_cleaned)
# Out:
# Duplicate rows found:
# Empty DataFrame
# Columns: [ID, Location , Unnamed: 2,  size(sqft), room, age(year), price(INR)]
# Index: []
# DataFrame after removing duplicate rows:
#    ID Location   Unnamed: 2   size(sqft)  room  age(year)  price(INR)
# 0   1  Downtown         NaN       1200.0   3.0       10.0   5000000.0
# 1   2    Suburb         NaN       1500.0   4.0        5.0   6500000.0
# 2   3    Uptown         NaN        100.0   2.0       20.0   3800000.0
# 3   4    Sunurb         NaN        200.0   5.0       10.0   7200000.0
# 4   5  Downtown         NaN        850.0   3.0       15.0   4200000.0
# 5   6    Uptown         NaN       1100.0   3.0       12.0   5600000.0
# 6   7    Suburb         NaN       1100.0   3.0        7.0   4800000.0
# 7   8  Downtown         NaN       1750.0   4.0        3.0   7000000.0
# 8   9    Uptown         NaN        950.0   2.0       25.0   3500000.0
# 9  10    Suburb         NaN       1600.0   4.0        6.0   5000000.0

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Select the numerical columns to normalize
numerical_cols_to_normalize = [' size(sqft)', 'age(year)']

# Apply Min-Max scaling to the selected columns
df_cleaned[numerical_cols_to_normalize] = scaler.fit_transform(df_cleaned[numerical_cols_to_normalize])

print("DataFrame after Min-Max scaling:")
display(df_cleaned)
# Out:
# DataFrame after Min-Max scaling:
#    ID Location   Unnamed: 2   size(sqft)  room  age(year)  price(INR)
# 0   1  Downtown         NaN     0.666667   3.0   0.318182   5000000.0
# 1   2    Suburb         NaN     0.848485   4.0   0.090909   6500000.0
# 2   3    Uptown         NaN     0.000000   2.0   0.772727   3800000.0
# 3   4    Sunurb         NaN     0.060606   5.0   0.318182   7200000.0
# 4   5  Downtown         NaN     0.454545   3.0   0.545455   4200000.0
# 5   6    Uptown         NaN     0.606061   3.0   0.409091   5600000.0
# 6   7    Suburb         NaN     0.606061   3.0   0.181818   4800000.0
# 7   8  Downtown         NaN     1.000000   4.0   0.000000   7000000.0
# 8   9    Uptown         NaN     0.515152   2.0   1.000000   3500000.0
# 9  10    Suburb         NaN     0.909091   4.0   0.136364   5000000.0

# %%
# Create a new feature: Price per Square Foot
df_cleaned['Price_per_SqFt'] = df_cleaned['price(INR)'] / df_cleaned[' size(sqft)']

print("\nDataFrame with new 'Price_per_SqFt' feature:")
display(df_cleaned)
# Out:
# DataFrame with new 'Price_per_SqFt' feature:
#    ID Location   Unnamed: 2   size(sqft)  room  age(year)  price(INR)  \
# 0   1  Downtown         NaN     0.666667   3.0   0.318182   5000000.0
# 1   2    Suburb         NaN     0.848485   4.0   0.090909   6500000.0
# 2   3    Uptown         NaN     0.000000   2.0   0.772727   3800000.0
# 3   4    Sunurb         NaN     0.060606   5.0   0.318182   7200000.0
# 4   5  Downtown         NaN     0.454545   3.0   0.545455   4200000.0
# 5   6    Uptown         NaN     0.606061   3.0   0.409091   5600000.0
# 6   7    Suburb         NaN     0.606061   3.0   0.181818   4800000.0
# 7   8  Downtown         NaN     1.000000   4.0   0.000000   7000000.0
# 8   9    Uptown         NaN     0.515152   2.0   1.000000   3500000.0
# 9  10    Suburb         NaN     0.909091   4.0   0.136364   5000000.0
#
#    Price_per_SqFt
# 0    7.500000e+06
# 1    7.660714e+06
# 2             inf
# 3    1.188000e+08
# 4    9.240000e+06
# 5    9.240000e+06
# 6    7.920000e+06
# 7    7.000000e+06
# 8    6.794118e+06
# 9    5.500000e+06

# %%
# Perform one-hot encoding on the 'Location ' column
df_encoded = pd.get_dummies(df_cleaned, columns=['Location '], dtype=int)

print("\nDataFrame after one-hot encoding:")
display(df_encoded)
# Out:
# DataFrame after one-hot encoding:
#    ID  Unnamed: 2   size(sqft)  room  age(year)  price(INR)  Price_per_SqFt  \
# 0   1         NaN     0.666667   3.0   0.318182   5000000.0    7.500000e+06
# 1   2         NaN     0.848485   4.0   0.090909   6500000.0    7.660714e+06
# 2   3         NaN     0.000000   2.0   0.772727   3800000.0             inf
# 3   4         NaN     0.060606   5.0   0.318182   7200000.0    1.188000e+08
# 4   5         NaN     0.454545   3.0   0.545455   4200000.0    9.240000e+06
# 5   6         NaN     0.606061   3.0   0.409091   5600000.0    9.240000e+06
# 6   7         NaN     0.606061   3.0   0.181818   4800000.0    7.920000e+06
# 7   8         NaN     1.000000   4.0   0.000000   7000000.0    7.000000e+06
# 8   9         NaN     0.515152   2.0   1.000000   3500000.0    6.794118e+06
# 9  10         NaN     0.909091   4.0   0.136364   5000000.0    5.500000e+06
#
#    Location _Downtown  Location _Suburb  Location _Sunurb  Location _Uptown
# 0                   1                 0                 0                 0
# 1                   0                 1                 0                 0
# 2                   0                 0                 0                 1
# 3                   0                 0                 1                 0
# 4                   1                 0                 0                 0
# 5                   0                 0                 0                 1
# 6                   0                 1                 0                 0
# 7                   1                 0                 0                 0
# 8                   0                 0                 0                 1
# 9                   0                 1                 0                 0
